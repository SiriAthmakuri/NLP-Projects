# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
import warnings
warnings.filterwarnings("ignore")

# %%
data=pd.read_csv("C:/Users/DELL/nlp/Sentimentdataset/sentimentdataset.csv")

# %%
data.shape
# Out:
# (732, 15)

# %%
data
# Out:
#      Unnamed: 0.1  Unnamed: 0  \
# 0               0           0
# 1               1           1
# 2               2           2
# 3               3           3
# 4               4           4
# ..            ...         ...
# 727           728         732
# 728           729         733
# 729           730         734
# 730           731         735
# 731           732         736
#
#                                                   Text    Sentiment  \
# 0     Enjoying a beautiful day at the park!        ...   Positive
# 1     Traffic was terrible this morning.           ...   Negative
# 2     Just finished an amazing workout! 💪          ...   Positive
# 3     Excited about the upcoming weekend getaway!  ...   Positive
# 4     Trying out a new recipe for dinner tonight.  ...   Neutral
# ..                                                 ...          ...
# 727  Collaborating on a science project that receiv...       Happy
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0.1  732 non-null    int64
#  1   Unnamed: 0    732 non-null    int64
#  2   Text          732 non-null    object
#  3   Sentiment     732 non-null    object
#  4   Timestamp     732 non-null    object
#  5   User          732 non-null    object
#  6   Platform      732 non-null    object
#  7   Hashtags      732 non-null    object
#  8   Retweets      732 non-null    float64
#  9   Likes         732 non-null    float64
#  10  Country       732 non-null    object
#  11  Year          732 non-null    int64
#  12  Month         732 non-null    int64
#  13  Day           732 non-null    int64
#  14  Hour          732 non-null    int64
# dtypes: float64(2), int64(6), object(7)
# memory usage: 85.9+ KB

# %%
data.describe()
# Out:
#        Unnamed: 0.1  Unnamed: 0    Retweets       Likes         Year  \
# count    732.000000  732.000000  732.000000  732.000000   732.000000
# mean     366.464481  369.740437   21.508197   42.901639  2020.471311
# std      211.513936  212.428936    7.061286   14.089848     2.802285
# min        0.000000    0.000000    5.000000   10.000000  2010.000000
# 25%      183.750000  185.750000   17.750000   34.750000  2019.000000
# 50%      366.500000  370.500000   22.000000   43.000000  2021.000000
# 75%      549.250000  553.250000   25.000000   50.000000  2023.000000
# max      732.000000  736.000000   40.000000   80.000000  2023.000000
#
#             Month         Day        Hour
# count  732.000000  732.000000  732.000000
# mean     6.122951   15.497268   15.521858
# std      3.411763    8.474553    4.113414
# min      1.000000    1.000000    0.000000
# 25%      3.000000    9.000000   13.000000
# 50%      6.000000   15.000000   16.000000
# 75%      9.000000   22.000000   19.000000
# ...

# %%
data.isnull().sum()
# Out:
# Unnamed: 0.1    0
# Unnamed: 0      0
# Text            0
# Sentiment       0
# Timestamp       0
# User            0
# Platform        0
# Hashtags        0
# Retweets        0
# Likes           0
# Country         0
# Year            0
# Month           0
# Day             0
# Hour            0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data = data.drop(['Unnamed: 0','Unnamed: 0.1','Timestamp'], axis = 1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Text       732 non-null    object
#  1   Sentiment  732 non-null    object
#  2   User       732 non-null    object
#  3   Platform   732 non-null    object
#  4   Hashtags   732 non-null    object
#  5   Retweets   732 non-null    float64
#  6   Likes      732 non-null    float64
#  7   Country    732 non-null    object
#  8   Year       732 non-null    int64
#  9   Month      732 non-null    int64
#  10  Day        732 non-null    int64
#  11  Hour       732 non-null    int64
# dtypes: float64(2), int64(4), object(6)
# memory usage: 68.8+ KB

# %%
data.nunique()
# Out:
# Text         707
# Sentiment    279
# User         685
# Platform       4
# Hashtags     697
# Retweets      26
# Likes         38
# Country      115
# Year          14
# Month         12
# Day           31
# Hour          22
# dtype: int64

# %%
import re
import nltk
from sklearn.feature_extraction.text import ENGLISH_STOP_WORDS as stop_words
from nltk.stem import WordNetLemmatizer

# %%
lemmatizer = WordNetLemmatizer()

# %%
def clean_text(text):
    # Remove special characters and replace them with spaces
    text = re.sub(r'\W', ' ', text)

    # Convert all characters to lowercase
    text = text.lower()

    # Tokenize the text (split it into individual words)
    words = text.split()

    # Remove stop words and lemmatize each word
    cleaned_words = [lemmatizer.lemmatize(word) for word in words if word not in stop_words]

    # Join the cleaned words back into a single string
    return ' '.join(cleaned_words)

# %%
data['cleaned_text'] = data['Text'].apply(clean_text)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Initialize a TF-IDF vectorizer with a maximum of 500 features (terms)
tfidf_vectorizer = TfidfVectorizer(max_features=500)

# Apply the TF-IDF vectorizer to the cleaned email text data and transform it into numerical features
inputs = tfidf_vectorizer.fit_transform(data['cleaned_text'])

# %%
X = data.drop('Sentiment', axis=1)
y= data.Sentiment.to_frame()

# %%
X_train , X_test , y_train , y_test = train_test_split(X,y,train_size=0.70,random_state=3)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (512, 12) (512, 1)
# (220, 12) (220, 1)

# %%
# Select all object (categorical) columns
X_train_cat = X_train.select_dtypes(include=['object'])

# Exclude a particular column (e.g., 'column_name')
X_train_cat = X_train_cat.drop(columns=['cleaned_text','Text'])

# Check the result
X_train_cat
# Out:
#                                   User     Platform  \
# 718        BirthdaySurpriseHighSchool    Instagram
# 598                 NostalgiaExplorer      Twitter
# 326                       RuinedHeart    Instagram
# 574   GardeningEnthusiastFlowerGarden    Instagram
# 224                 VisionarySpirit      Instagram
# ..                                 ...          ...
# 659              TikTokFailHighSchool     Facebook
# 256                   PhoenixExplorer      Twitter
# 643            CodeExplorerHighSchool      Twitter
# 249                      DreamPainter    Instagram
# 664              SnackNinjaHighSchool      Twitter
#
#                                        Hashtags          Country
# 718      #SurpriseParty #HighSchoolCelebration                UK
# 598           #ChildhoodMemories #TeenCartoons               USA
# 326       #Devastated #EchoesOfShatteredDreams        Australia
# 574                  #NaturesBeauty #FloralJoy        Australia
# ...

# %%
X_train_num = X_train.select_dtypes(include=['int64','float64'])

# %%
# Select all object (categorical) columns
X_test_cat = X_test.select_dtypes(include=['object'])

# Exclude a particular column (e.g., 'column_name')
X_test_cat = X_test_cat.drop(columns=['cleaned_text','Text'])

# Check the result
X_test_cat
# Out:
#                             User     Platform  \
# 80              NewParentJoy       Instagram
# 97              KindnessObserver    Twitter
# 559   SoccerPlayerOwnGoalMoment      Twitter
# 406              FamilyGatherer     Facebook
# 124             SimpleJoys          Twitter
# ..                           ...          ...
# 30                 RoadTripper     Instagram
# 322               NightPrisoner      Twitter
# 114             OptimisticSoul      Facebook
# 458              TapestrySorrow     Facebook
# 453               RiverOfSorrow    Instagram
#
#                                              Hashtags            Country
# 80       #Happiness #NewFamilyMember                       UK
# 97        #Kindness #ActsOfKindness                           USA
# 559                                #Despair #OwnGoal              Spain
# 406          #Gratitude #FamilyLaughter                 Austria
# 124    #Contentment #SundayMood                               Australia
# ...

# %%
X_test_num = X_test.select_dtypes(include=['int64','float64'])

# %%
scaler = StandardScaler()
X_train_num_rescaled = pd.DataFrame(scaler.fit_transform(X_train_num),
                                   columns=X_train_num.columns,
                                   index=X_train_num.index)
X_test_num_rescaled = pd.DataFrame(scaler.transform(X_test_num),
                                   columns=X_test_num.columns,
                                   index=X_test_num.index)
X_train_num_rescaled.head()
X_test_num_rescaled.head()
# Out:
#      Retweets     Likes      Year     Month       Day      Hour
# 80   1.223194  1.235839  0.909588 -1.224642  0.771996 -1.366951
# 97  -0.203076 -0.193619  0.909588 -1.224642  1.487402 -1.120948
# 559  0.082178  0.163745 -0.982000  1.731589 -0.062645  1.093080
# 406  0.082178  0.163745 -1.360318  1.731589  1.487402  0.847077
# 124  1.223194  1.235839 -4.008542  0.549097 -0.062645 -1.366951

# %%
from sklearn.preprocessing import LabelEncoder

# Initialize the LabelEncoder
label_encoder = LabelEncoder()

# Apply label encoding to each column in X_train_encoded and X_test_encoded
# Make sure the columns in X_train_encoded and X_test_encoded are categorical

# For X_train_encoded
X_train_encoded= X_train_encoded.apply(label_encoder.fit_transform)

# For X_test_encoded (ensure to use the same encoder for consistency)
X_test_encoded= X_test_encoded.apply(label_encoder.transform)

# %%
X_train_encoded
# Out:
#      User_ AdeleConcertGoer   User_ AdeleMelodyTearjerker   \
# 718                        0                             0
# 598                        0                             0
# 326                        0                             0
# 574                        0                             0
# 224                        0                             0
# ..                       ...                           ...
# 659                        0                             0
# 256                        0                             0
# 643                        0                             0
# 249                        0                             0
# 664                        0                             0
#
#      User_ AdventureAwaits    User_ AdventureSeeker   User_ AdventureX     \
# 718                        0                       0                    0
# 598                        0                       0                    0
# ...

# %%
X_test_encoded
# Out:
#      User_ AdventureAwaits   User_ AngkorWatAdventurer   \
# 80                        0                           0
# 97                        0                           0
# 559                       0                           0
# 406                       0                           0
# 124                       0                           0
# ..                      ...                         ...
# 30                        0                           0
# 322                       0                           0
# 114                       0                           0
# 458                       0                           0
# 453                       0                           0
#
#      User_ ApatheticObserver   User_ ArchaeologyEnthusiast   \
# 80                          0                             0
# 97                          0                             0
# 559                         0                             0
# ...

# %%
X_test_encoded = X_test_encoded.reindex(columns=X_train_encoded.columns, fill_value=0)

# %%
X_test_encoded.shape
# Out:
# (220, 1079)

# %%
X_train_encoded.shape
# Out:
# (512, 1079)

# %%
X_train_transformed = pd.concat([X_train_num_rescaled, X_train_encoded,data['cleaned_text']], axis=1)
X_test_transformed = pd.concat([X_test_num_rescaled, X_test_encoded], axis=1)
